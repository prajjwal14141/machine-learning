# %% [markdown]
# #### Distribution plots - for quantitative data, can give a specific col or entire dataset at once
#
# 1- histogram(binning based, can be of entire dataset or a certain col)  --   sb.histplot(dataset['column'], bins = n, kde = True)....|| n=20 by default
#
# 2 - jointplots(two cols) --  sb.jointplot(x= 'col1', y= 'col2',data='dataset', kind = 'scatter) ... || ... kind = scatter/hex/reg/kde ,etc
#
# 3- pairplot(all posible pairs of quant. cols)  -- sb.pairplot(data, hue='abc', palette='clr_pattern') ... || ... hue tells for basis of distribution

# %%
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

df = sb.load_dataset('tips')    #load from github of sb
sb.histplot(df['tip'], bins = 30, kde = 1)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# USE PLT.SUBPLOT ALONG WITH FOR MAN PLOTS
plt.subplot(1, 2, 1)
sb.histplot(df['tip'], bins = 30, kde = 1)
plt.subplot(1, 2, 2)
sb.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#JOINT-PLOT , PairPlot and rugPlot
sb.rugplot(df['tip']), sb.jointplot(x = 'tip', y='total_bill', data = df), sb.pairplot(df, hue='size', palette='rainbow')
# Out:
# (<Axes: xlabel='tip'>,
# ...
#  <seaborn.axisgrid.PairGrid at 0x226cf7be490>)

# %%
arr = [1,1,1,1,1,1,2,3,4,4,4,1]
print(arr[7])
# Out:
# 3

# %% [markdown]
# ## CATEGORICAL PLOTS
# 1- Countplot                                --- sb.countplt(x = df['col1'], hue = 'col2')
#
# 2- Barplot x(qaulitative), y(quant)         --- sb.barplot(x= df['qualt], y=df['quant'], estimator = np.fn)
#
# ##### boxplot and violinplot
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# 3- BoxPlot                                  --- sb.boxplot(x = 'quant', y='qualt, data = df, palette = 'rainbow')
#
# 4- VoilenPlot                               --- sb.voilenplot(x = 'quant', y='qualt, data = df, palette = 'rainbow')
# ##### stripplot and swarmplot
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).
#
# 5- StripPlot                               --- sb.stripplot(x = 'quant', y='qualt, data = df, palette = 'rainbow')
#
# 6- SwarmPlot                               --- sb.swarmplot(x = 'quant', y='qualt, data = df, palette = 'rainbow')

# %%
sb.countplot(x = df['sex'], hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sb.barplot(x=df['sex'], y=df['total_bill'], estimator=np.median)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sb.boxplot(x = 'tip', y='day', data = df, palette = 'rainbow')
# Out:
# C:\Users\prajj\AppData\Local\Temp\ipykernel_23132\1609415691.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x = 'tip', y='day', data = df, palette = 'rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
sb.violinplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# Out:
# C:\Users\prajj\AppData\Local\Temp\ipykernel_23132\4029592441.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sb.stripplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# Out:
# C:\Users\prajj\AppData\Local\Temp\ipykernel_23132\3559973840.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.stripplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='tip'>

# %%
sb.swarmplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# Out:
# C:\Users\prajj\AppData\Local\Temp\ipykernel_23132\1631797128.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.swarmplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='tip'>

# %%
# COMBINING  PLOTS --- THEY DEPICT SAME DISTRIBUTION
sb.swarmplot(x = 'day', y='tip', data = df, palette = 'rainbow')
sb.violinplot(x = 'day', y='tip', data = df,color='green')
# sb.boxplot(x = 'day', y='tip', data = df, color=  'black')
# Out:
# C:\Users\prajj\AppData\Local\Temp\ipykernel_23132\3714891862.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.swarmplot(x = 'day', y='tip', data = df, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='tip'>
